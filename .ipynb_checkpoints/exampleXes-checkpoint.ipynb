# %%
#!/usr/bin/env python

import xes

traces = [
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ]
]


log = xes.Log()
for trace in traces:
    t = xes.Trace()
    for event in trace:
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="concept:name", value=event["concept:name"]),
            xes.Attribute(type="string", key="org:resource", value=event["org:resource"])
        ]
        t.add_event(e)
    log.add_trace(t)
log.classifiers = [
    xes.Classifier(name="org:resource",keys="org:resource"),
    xes.Classifier(name="concept:name",keys="concept:name")
]

open("example.xes", "w").write(str(log))

# %%
#!/usr/bin/env python
# squential
import xes
from random import randint
print(randint(0,99))

traces = [
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ]
]

serviceName = ["2D_Map","Empirical-Orthogonal-\\nFunction-(EOF)-Analysis","3-D-Variable-2-D-Slice","Scatter-and-Histogram-Plot\\n-of-Two-Variables","Difference-Plot-of-Two\\n-Time-Averaged-Variables","Time-Lagged-Correlation-Map\\n-of-Two-Variables","Random-Forest-Importance","Conditional-Probability\\n-Density-Function","Anomaly-Calculation","Time-Series","2-D-Variable-Zonal-Mean","3-D-Variable-Zonal-Mean","3-D-Variable-Average-\\nVertical-Profile","Map-View","Conditional-Sampling\\n-with-Two-Variables","Regrid-and-Download","Conditional-Sampling\\n-with-One-Variable","Time-Series-for-Work-Flow"]

print(serviceName[0])

log = xes.Log()
for trace in range(1,100):
    t = xes.Trace()
    for event in range(0,4):
        if (randint(0,99) < 99 - event*event*2):
            e = xes.Event()
            e.attributes = [
                xes.Attribute(type="string", key="org:resource", value=serviceName[event])
            ]
            t.add_event(e)
    log.add_trace(t)
log.classifiers = [
    xes.Classifier(name="org:resource",keys="org:resource")
]

open("example1.xes", "w").write(str(log))
# Out:
# 73
# 2D_Map

# %%
#!/usr/bin/env python
# AND join
import xes
from random import randint
print(randint(0,99))

traces = [
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ]
]

serviceName = ["2D_Map","Empirical-Orthogonal-\\nFunction-(EOF)-Analysis","3-D-Variable-2-D-Slice","Scatter-and-Histogram-Plot\\n-of-Two-Variables","Difference-Plot-of-Two\\n-Time-Averaged-Variables","Time-Lagged-Correlation-Map\\n-of-Two-Variables","Random-Forest-Importance","Conditional-Probability\\n-Density-Function","Anomaly-Calculation","Time-Series","2-D-Variable-Zonal-Mean","3-D-Variable-Zonal-Mean","3-D-Variable-Average-\\nVertical-Profile","Map-View","Conditional-Sampling\\n-with-Two-Variables","Regrid-and-Download","Conditional-Sampling\\n-with-One-Variable","Time-Series-for-Work-Flow"]


print(serviceName[0])

log = xes.Log()
for trace in range(1,100):
    t = xes.Trace()
    
    if (randint(0,99) < 60):
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[5])
        ]
        t.add_event(e)

        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[6])
        ]
        t.add_event(e)

    else:
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[6])
        ]
        t.add_event(e)   

        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[5])
        ]
        t.add_event(e)

    e = xes.Event()
    e.attributes = [
        xes.Attribute(type="string", key="org:resource", value=serviceName[9])
    ]
    t.add_event(e)
        
    log.add_trace(t)
log.classifiers = [
    xes.Classifier(name="org:resource",keys="org:resource")
]

open("example2.xes", "w").write(str(log))
# Out:
# 50
# 2D_Map

# %%
#!/usr/bin/env python
# Or join
import xes
from random import randint
print(randint(0,99))

traces = [
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ]
]

serviceName = ["2D_Map","Empirical-Orthogonal-\\nFunction-(EOF)-Analysis","3-D-Variable-2-D-Slice","Scatter-and-Histogram-Plot\\n-of-Two-Variables","Difference-Plot-of-Two\\n-Time-Averaged-Variables","Time-Lagged-Correlation-Map\\n-of-Two-Variables","Random-Forest-Importance","Conditional-Probability\\n-Density-Function","Anomaly-Calculation","Time-Series","2-D-Variable-Zonal-Mean","3-D-Variable-Zonal-Mean","3-D-Variable-Average-\\nVertical-Profile","Map-View","Conditional-Sampling\\n-with-Two-Variables","Regrid-and-Download","Conditional-Sampling\\n-with-One-Variable","Time-Series-for-Work-Flow"]


print(serviceName[0])

log = xes.Log()
for trace in range(1,100):
    t = xes.Trace()
    
    if (randint(0,99) < 60):
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[5])
        ]
        t.add_event(e)

    else:
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[7])
        ]
        t.add_event(e)   

    e = xes.Event()
    e.attributes = [
        xes.Attribute(type="string", key="org:resource", value=serviceName[8])
    ]
    t.add_event(e)
        
    log.add_trace(t)
log.classifiers = [
    xes.Classifier(name="org:resource",keys="org:resource")
]

open("example3.xes", "w").write(str(log))
# Out:
# 80
# 2D_Map

# %%
#!/usr/bin/env python
# Or split
import xes
from random import randint
print(randint(0,99))

traces = [
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ]
]

serviceName = ["2D_Map","Empirical-Orthogonal-\\nFunction-(EOF)-Analysis","3-D-Variable-2-D-Slice","Scatter-and-Histogram-Plot\\n-of-Two-Variables","Difference-Plot-of-Two\\n-Time-Averaged-Variables","Time-Lagged-Correlation-Map\\n-of-Two-Variables","Random-Forest-Importance","Conditional-Probability\\n-Density-Function","Anomaly-Calculation","Time-Series","2-D-Variable-Zonal-Mean","3-D-Variable-Zonal-Mean","3-D-Variable-Average-\\nVertical-Profile","Map-View","Conditional-Sampling\\n-with-Two-Variables","Regrid-and-Download","Conditional-Sampling\\n-with-One-Variable","Time-Series-for-Work-Flow"]


print(serviceName[0])

log = xes.Log()
for trace in range(1,100):
    t = xes.Trace()
    
    e = xes.Event()
    e.attributes = [
        xes.Attribute(type="string", key="org:resource", value=serviceName[10])
    ]
    t.add_event(e)
    
    if (randint(0,99) < 60):
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[2])
        ]
        t.add_event(e)

    else:
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[3])
        ]
        t.add_event(e)   

        
    log.add_trace(t)
log.classifiers = [
    xes.Classifier(name="org:resource",keys="org:resource")
]

open("example4.xes", "w").write(str(log))
# Out:
# 83
# 2D_Map

# %%
#!/usr/bin/env python
# And split
import xes
from random import randint
print(randint(0,99))

traces = [
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Negotiate", "org:resource" : "Sally"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ],
    [
        {"concept:name" : "Register", "org:resource" : "Bob"},
        {"concept:name" : "Sign", "org:resource" : "Dan"},
        {"concept:name" : "Sendoff", "org:resource" : "Mary"}
    ]
]

serviceName = ["2D_Map","Empirical-Orthogonal-\\nFunction-(EOF)-Analysis","3-D-Variable-2-D-Slice","Scatter-and-Histogram-Plot\\n-of-Two-Variables","Difference-Plot-of-Two\\n-Time-Averaged-Variables","Time-Lagged-Correlation-Map\\n-of-Two-Variables","Random-Forest-Importance","Conditional-Probability\\n-Density-Function","Anomaly-Calculation","Time-Series","2-D-Variable-Zonal-Mean","3-D-Variable-Zonal-Mean","3-D-Variable-Average-\\nVertical-Profile","Map-View","Conditional-Sampling\\n-with-Two-Variables","Regrid-and-Download","Conditional-Sampling\\n-with-One-Variable","Time-Series-for-Work-Flow"]


print(serviceName[0])

log = xes.Log()
for trace in range(1,100):
    t = xes.Trace()
    
    e = xes.Event()
    e.attributes = [
        xes.Attribute(type="string", key="org:resource", value=serviceName[6])
    ]
    t.add_event(e)
    
    if (randint(0,99) < 60):
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[2])
        ]
        t.add_event(e)
        
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[3])
        ]
        t.add_event(e)

    else:
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[3])
        ]
        t.add_event(e)   
        
        e = xes.Event()
        e.attributes = [
            xes.Attribute(type="string", key="org:resource", value=serviceName[2])
        ]
        t.add_event(e)

        
    log.add_trace(t)
log.classifiers = [
    xes.Classifier(name="org:resource",keys="org:resource")
]

open("example5.xes", "w").write(str(log))
# Out:
# 1
# 2D_Map
